# %%
import keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, Dropout, BatchNormalization, Dense, Flatten, LayerNormalization
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.applications as appl
from sklearn.model_selection import train_test_split
import os
import cv2
import time
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics as metrics
from tqdm import tqdm
from tensorflow.keras.utils import Sequence
from keras import callbacks  
from keras.models import load_model
from keras.utils import np_utils

# %%
load_path='E:/VA/onehandtwohand/128/106words_DSLR_FH/'

# %%
CATEGORIES=np.load(load_path+'cat_106.npy', allow_pickle=True)

# %%
IMG_SIZE=128

# %%
cat_len=len(CATEGORIES)
print(cat_len)
# Out:
# 106

# %% [markdown]
# # Save combined data npy

# %%
# model

# model_name1 = 'InceptionResNetV2'
# model_name1 = '4layer'
model_name1 = '15layer_lr0.00001_106words_dslr128-99.79'
#model_name2 = 'VGG16'
# model_name1 = 'DenseNet121'
# model_name1 = 'InceptionV3'

# %% [markdown]
# Loading

# %%
X=np.load(load_path+'X_dslr.npy', allow_pickle=True)
Y=np.load(load_path+'Y_dslr.npy', allow_pickle=True)

# %%
X = X.astype('float32')
X /= 255

# %%
print('Splitting') 
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = cat_len)
X_train, X_new, y_train, y_new = train_test_split(X_train, y_train, test_size = 0.2, random_state = cat_len)
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
X_new = np.array(X_new)
y_new = np.array(y_new)

print("pass")
# Out:
# Splitting
# pass

# %%
del X,Y

# %%
print('Image Data Augmentation')
from keras.preprocessing.image import ImageDataGenerator
val_generator = ImageDataGenerator(rotation_range=0, zoom_range=0.2, width_shift_range=0.2,
    height_shift_range=0.2, shear_range=0.2)
#                                     , horizontal_flip=True, brightness_range=[0.6,1.3])
val_generator.fit(X_train)
val_generator.fit(X_new)
val_generator.fit(X_test)

print("done")
# Out:
# Image Data Augmentation
# done

# %%
#layers:15
#change:added batchnorm:+5, layernorm: +`1,learning_rate=0.00001
# # output: valacc:  acc:  %, val_loss:

model = Sequential()

model.add(Conv2D(32, (5, 5), input_shape = (IMG_SIZE,IMG_SIZE,3), padding='same', activation='relu'))         #1
# model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(BatchNormalization())

model.add(Conv2D(32, (5, 5), padding='same', activation='relu'))                                              #2
# model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))


model.add(Conv2D(64, (5, 5), padding='same', activation='relu'))                                              #2
model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(BatchNormalization())

model.add(Conv2D(64, (5, 5), padding='same', activation='relu'))                                              #2
# model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(Conv2D(128, (5, 5), padding='same', activation='relu'))                                              #3
# model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(BatchNormalization())

model.add(Conv2D(128, (5, 5), padding='same', activation='relu'))                                              #4
model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(Conv2D(256, (5, 5), padding='same', activation='relu'))                                              #5
# model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(BatchNormalization())

model.add(Conv2D(512, (5, 5), padding='same', activation='relu'))                                              #6
# model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))                                             #7
model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.20))

model.add(BatchNormalization())

model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))                                             #8
# model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))                                              #2
# model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

# model.add(LayerNormalization())

model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))                                              #2
model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(Flatten())

model.add(Dense(2048, activation = 'relu'))
model.add(Dropout(0.80))
model.add(Dense(1024, activation = 'relu'))
model.add(Dropout(0.80))
model.add(Dense(cat_len, activation = 'softmax'))                                               #11

model1=model
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      2432
#
#  batch_normalization (BatchN  (None, 128, 128, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      25632
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 64)      51264
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 64)       0
#  )
#
#  batch_normalization_1 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 64)        102464
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 128)       204928
#
#  batch_normalization_2 (Batc  (None, 64, 64, 128)      512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 128)       409728
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 256)       819456
#
#  batch_normalization_3 (Batc  (None, 32, 32, 256)      1024
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 512)       3277312
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 256)       1179904
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 256)      0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 128)       295040
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 64)        73792
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 32)        18464
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 2048)              4196352
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 106)               108650
#
# =================================================================
# Total params: 12,866,538
# Trainable params: 12,865,066
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
print('Training model 1')
opt = Adam(learning_rate=0.00001)
earlystopping = callbacks.EarlyStopping(monitor="val_loss", patience = 10, restore_best_weights = True)
model1.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])
# model1.summary()



history_const = model1.fit(X_train, y_train,batch_size=50, epochs = 1000, validation_data=(X_test,y_test),
                   callbacks= [earlystopping])
# Out:
# Training model 1
# Epoch 1/1000
# 487/487 [==============================] - 59s 110ms/step - loss: 4.9384 - accuracy: 0.0127 - val_loss: 4.6411 - val_accuracy: 0.0184
# Epoch 2/1000
# 487/487 [==============================] - 48s 98ms/step - loss: 4.6552 - accuracy: 0.0152 - val_loss: 4.5556 - val_accuracy: 0.1290
# Epoch 3/1000
# 487/487 [==============================] - 48s 98ms/step - loss: 4.5797 - accuracy: 0.0224 - val_loss: 4.4273 - val_accuracy: 0.1875
# Epoch 4/1000
# 487/487 [==============================] - 48s 98ms/step - loss: 4.4534 - accuracy: 0.0393 - val_loss: 4.1584 - val_accuracy: 0.2355
# Epoch 5/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 4.2512 - accuracy: 0.0655 - val_loss: 3.7976 - val_accuracy: 0.3049
# Epoch 6/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 4.0439 - accuracy: 0.0965 - val_loss: 3.4506 - val_accuracy: 0.3278
# Epoch 7/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 3.8284 - accuracy: 0.1315 - val_loss: 3.1862 - val_accuracy: 0.3717
# Epoch 8/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 3.6375 - accuracy: 0.1605 - val_loss: 2.9455 - val_accuracy: 0.4060
# Epoch 9/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 3.4581 - accuracy: 0.1919 - val_loss: 2.7729 - val_accuracy: 0.4425
# Epoch 10/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 3.3093 - accuracy: 0.2164 - val_loss: 2.6401 - val_accuracy: 0.4695
# Epoch 11/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 3.1613 - accuracy: 0.2404 - val_loss: 2.4260 - val_accuracy: 0.5021
# Epoch 12/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 3.0113 - accuracy: 0.2667 - val_loss: 2.2772 - val_accuracy: 0.5349
# Epoch 13/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 2.8777 - accuracy: 0.2923 - val_loss: 2.1019 - val_accuracy: 0.5611
# Epoch 14/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 2.7575 - accuracy: 0.3164 - val_loss: 2.0280 - val_accuracy: 0.5792
# Epoch 15/1000
# 487/487 [==============================] - 50s 102ms/step - loss: 2.6143 - accuracy: 0.3429 - val_loss: 1.8401 - val_accuracy: 0.6144
# Epoch 16/1000
# 487/487 [==============================] - 49s 101ms/step - loss: 2.5123 - accuracy: 0.3623 - val_loss: 1.7069 - val_accuracy: 0.6199
# Epoch 17/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 2.3911 - accuracy: 0.3881 - val_loss: 1.5784 - val_accuracy: 0.6618
# Epoch 18/1000
# 487/487 [==============================] - 51s 106ms/step - loss: 2.2921 - accuracy: 0.4055 - val_loss: 1.5260 - val_accuracy: 0.6916
# Epoch 19/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 2.1764 - accuracy: 0.4283 - val_loss: 1.3777 - val_accuracy: 0.7132
# Epoch 20/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 2.0646 - accuracy: 0.4565 - val_loss: 1.2832 - val_accuracy: 0.7439
# Epoch 21/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 1.9523 - accuracy: 0.4798 - val_loss: 1.1942 - val_accuracy: 0.7479
# Epoch 22/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 1.8612 - accuracy: 0.4995 - val_loss: 1.1197 - val_accuracy: 0.7750
# Epoch 23/1000
# 487/487 [==============================] - 48s 100ms/step - loss: 1.7595 - accuracy: 0.5218 - val_loss: 1.0053 - val_accuracy: 0.7902
# Epoch 24/1000
# 487/487 [==============================] - 48s 100ms/step - loss: 1.6699 - accuracy: 0.5470 - val_loss: 0.9131 - val_accuracy: 0.8061
# Epoch 25/1000
# 487/487 [==============================] - 48s 100ms/step - loss: 1.5890 - accuracy: 0.5625 - val_loss: 0.8656 - val_accuracy: 0.8305
# Epoch 26/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 1.4982 - accuracy: 0.5834 - val_loss: 0.7885 - val_accuracy: 0.8383
# Epoch 27/1000
# 487/487 [==============================] - 49s 101ms/step - loss: 1.4168 - accuracy: 0.6056 - val_loss: 0.7381 - val_accuracy: 0.8463
# Epoch 28/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 1.3340 - accuracy: 0.6245 - val_loss: 0.6573 - val_accuracy: 0.8616
# Epoch 29/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 1.2444 - accuracy: 0.6496 - val_loss: 0.5922 - val_accuracy: 0.8776
# Epoch 30/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 1.1797 - accuracy: 0.6631 - val_loss: 0.5599 - val_accuracy: 0.8846
# Epoch 31/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 1.1169 - accuracy: 0.6820 - val_loss: 0.4729 - val_accuracy: 0.8927
# Epoch 32/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 1.0410 - accuracy: 0.6997 - val_loss: 0.4558 - val_accuracy: 0.9055
# Epoch 33/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.9688 - accuracy: 0.7213 - val_loss: 0.4154 - val_accuracy: 0.9208
# Epoch 34/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.9064 - accuracy: 0.7358 - val_loss: 0.3882 - val_accuracy: 0.9172
# Epoch 35/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.8581 - accuracy: 0.7484 - val_loss: 0.3486 - val_accuracy: 0.9301
# Epoch 36/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.7994 - accuracy: 0.7677 - val_loss: 0.2620 - val_accuracy: 0.9501
# Epoch 37/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.7407 - accuracy: 0.7833 - val_loss: 0.2580 - val_accuracy: 0.9550
# Epoch 38/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.6824 - accuracy: 0.7975 - val_loss: 0.2706 - val_accuracy: 0.9424
# Epoch 39/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.6508 - accuracy: 0.8099 - val_loss: 0.2184 - val_accuracy: 0.9600
# Epoch 40/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.6067 - accuracy: 0.8209 - val_loss: 0.1987 - val_accuracy: 0.9597
# Epoch 41/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.5595 - accuracy: 0.8348 - val_loss: 0.1736 - val_accuracy: 0.9630
# Epoch 42/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.5281 - accuracy: 0.8404 - val_loss: 0.1676 - val_accuracy: 0.9677
# Epoch 43/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.4842 - accuracy: 0.8563 - val_loss: 0.1466 - val_accuracy: 0.9671
# Epoch 44/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.4646 - accuracy: 0.8608 - val_loss: 0.1393 - val_accuracy: 0.9729
# Epoch 45/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.4303 - accuracy: 0.8706 - val_loss: 0.1038 - val_accuracy: 0.9775
# Epoch 46/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.3982 - accuracy: 0.8812 - val_loss: 0.1135 - val_accuracy: 0.9771
# Epoch 47/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.3703 - accuracy: 0.8881 - val_loss: 0.0958 - val_accuracy: 0.9788
# Epoch 48/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.3526 - accuracy: 0.8928 - val_loss: 0.1365 - val_accuracy: 0.9698
# Epoch 49/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.3157 - accuracy: 0.9068 - val_loss: 0.0804 - val_accuracy: 0.9827
# Epoch 50/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.3118 - accuracy: 0.9047 - val_loss: 0.0774 - val_accuracy: 0.9829
# Epoch 51/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.2918 - accuracy: 0.9115 - val_loss: 0.0673 - val_accuracy: 0.9850
# Epoch 52/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.2631 - accuracy: 0.9188 - val_loss: 0.0809 - val_accuracy: 0.9810
# Epoch 53/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.2435 - accuracy: 0.9259 - val_loss: 0.0524 - val_accuracy: 0.9880
# Epoch 54/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.2333 - accuracy: 0.9287 - val_loss: 0.0547 - val_accuracy: 0.9870
# Epoch 55/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.2246 - accuracy: 0.9317 - val_loss: 0.0462 - val_accuracy: 0.9906
# Epoch 56/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.2139 - accuracy: 0.9344 - val_loss: 0.0539 - val_accuracy: 0.9883
# Epoch 57/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.2019 - accuracy: 0.9383 - val_loss: 0.0463 - val_accuracy: 0.9892
# Epoch 58/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.1846 - accuracy: 0.9419 - val_loss: 0.0466 - val_accuracy: 0.9873
# Epoch 59/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.1823 - accuracy: 0.9444 - val_loss: 0.0441 - val_accuracy: 0.9904
# Epoch 60/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.1638 - accuracy: 0.9492 - val_loss: 0.0468 - val_accuracy: 0.9893
# Epoch 61/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.1511 - accuracy: 0.9540 - val_loss: 0.0485 - val_accuracy: 0.9906
# Epoch 62/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.1458 - accuracy: 0.9557 - val_loss: 0.0461 - val_accuracy: 0.9889
# Epoch 63/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.1394 - accuracy: 0.9565 - val_loss: 0.0293 - val_accuracy: 0.9923
# Epoch 64/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.1286 - accuracy: 0.9595 - val_loss: 0.0310 - val_accuracy: 0.9946
# Epoch 65/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.1235 - accuracy: 0.9615 - val_loss: 0.0785 - val_accuracy: 0.9866
# Epoch 66/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.1142 - accuracy: 0.9657 - val_loss: 0.2545 - val_accuracy: 0.9301
# Epoch 67/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.1118 - accuracy: 0.9652 - val_loss: 0.0247 - val_accuracy: 0.9937
# Epoch 68/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.1117 - accuracy: 0.9659 - val_loss: 0.0275 - val_accuracy: 0.9949
# Epoch 69/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.1042 - accuracy: 0.9680 - val_loss: 0.0641 - val_accuracy: 0.9842
# Epoch 70/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0974 - accuracy: 0.9693 - val_loss: 0.0264 - val_accuracy: 0.9943
# Epoch 71/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0955 - accuracy: 0.9698 - val_loss: 0.0181 - val_accuracy: 0.9950
# Epoch 72/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0858 - accuracy: 0.9722 - val_loss: 0.0285 - val_accuracy: 0.9938
# Epoch 73/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0833 - accuracy: 0.9739 - val_loss: 0.0493 - val_accuracy: 0.9878
# Epoch 74/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0829 - accuracy: 0.9741 - val_loss: 0.0337 - val_accuracy: 0.9939
# Epoch 75/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0790 - accuracy: 0.9765 - val_loss: 0.0762 - val_accuracy: 0.9765
# Epoch 76/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0810 - accuracy: 0.9747 - val_loss: 0.0180 - val_accuracy: 0.9952
# Epoch 77/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0723 - accuracy: 0.9779 - val_loss: 0.0121 - val_accuracy: 0.9965
# Epoch 78/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0627 - accuracy: 0.9808 - val_loss: 0.0162 - val_accuracy: 0.9954
# Epoch 79/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0690 - accuracy: 0.9789 - val_loss: 0.0205 - val_accuracy: 0.9949
# Epoch 80/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0665 - accuracy: 0.9796 - val_loss: 0.0193 - val_accuracy: 0.9952
# Epoch 81/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0598 - accuracy: 0.9820 - val_loss: 0.0166 - val_accuracy: 0.9958
# Epoch 82/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0580 - accuracy: 0.9821 - val_loss: 0.0136 - val_accuracy: 0.9969
# Epoch 83/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0563 - accuracy: 0.9818 - val_loss: 0.2363 - val_accuracy: 0.9330
# Epoch 84/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0615 - accuracy: 0.9810 - val_loss: 0.0194 - val_accuracy: 0.9954
# Epoch 85/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0532 - accuracy: 0.9839 - val_loss: 0.0109 - val_accuracy: 0.9969
# Epoch 86/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0533 - accuracy: 0.9834 - val_loss: 0.0243 - val_accuracy: 0.9939
# Epoch 87/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0513 - accuracy: 0.9837 - val_loss: 0.0109 - val_accuracy: 0.9975
# Epoch 88/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0462 - accuracy: 0.9857 - val_loss: 0.0131 - val_accuracy: 0.9967
# Epoch 89/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0464 - accuracy: 0.9853 - val_loss: 0.0118 - val_accuracy: 0.9963
# Epoch 90/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0475 - accuracy: 0.9853 - val_loss: 0.0172 - val_accuracy: 0.9956
# Epoch 91/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0439 - accuracy: 0.9868 - val_loss: 0.0130 - val_accuracy: 0.9964
# Epoch 92/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0449 - accuracy: 0.9862 - val_loss: 0.0298 - val_accuracy: 0.9922
# Epoch 93/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0422 - accuracy: 0.9864 - val_loss: 0.0236 - val_accuracy: 0.9939
# Epoch 94/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0363 - accuracy: 0.9887 - val_loss: 0.0077 - val_accuracy: 0.9979
# Epoch 95/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0423 - accuracy: 0.9861 - val_loss: 0.0214 - val_accuracy: 0.9940
# Epoch 96/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0377 - accuracy: 0.9880 - val_loss: 0.0285 - val_accuracy: 0.9923
# Epoch 97/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0370 - accuracy: 0.9883 - val_loss: 0.0393 - val_accuracy: 0.9898
# Epoch 98/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0373 - accuracy: 0.9880 - val_loss: 0.0285 - val_accuracy: 0.9928
# Epoch 99/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0320 - accuracy: 0.9901 - val_loss: 0.0179 - val_accuracy: 0.9952
# Epoch 100/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0348 - accuracy: 0.9890 - val_loss: 0.0092 - val_accuracy: 0.9979
# Epoch 101/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0354 - accuracy: 0.9890 - val_loss: 0.0150 - val_accuracy: 0.9962
# Epoch 102/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0326 - accuracy: 0.9895 - val_loss: 0.0146 - val_accuracy: 0.9966
# Epoch 103/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0326 - accuracy: 0.9897 - val_loss: 0.0120 - val_accuracy: 0.9973
# Epoch 104/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.0306 - accuracy: 0.9908 - val_loss: 0.1143 - val_accuracy: 0.9726

# %%
print('Saving')
np.save(load_path+model_name1+'_history.npy',history_const.history)
model1.save(load_path+model_name1+'_model.h5') 
print("saved")
# Out:
# Saving
# saved

# %%
# #load saved history
history_const=np.load(load_path+model_name1+'_history.npy',allow_pickle='TRUE').item()

# #load saved model
model1=load_model(load_path+model_name1+'_model.h5')

print("loaded")
# Out:
# loaded

# %%
print('Plots')
plt.plot(history_const.history['loss'])
plt.plot(history_const.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
# plt.savefig('F:/VA/onehandtwohand/26words_DSLR_results/'+model_name1+'_loss.png')
plt.savefig(load_path+model_name1+'_loss.png')
plt.show()
plt.plot(history_const.history['accuracy'])
plt.plot(history_const.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')

plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig(load_path+model_name1+'_accuracy.png')
plt.show()
# Out:
# Plots

# %%
print('Confusion matrix')
Y_pred = model1.predict(X_new)
y_pred = np.argmax(Y_pred, axis=1)
y_test1 = np.argmax(y_new, axis=1)

cm=metrics.confusion_matrix(y_test1, y_pred)


cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
a4_dims = (200, 100)
fig,ax= plt.subplots(figsize=a4_dims)
sns.heatmap(cm, annot=True, fmt=".2f", ax=ax,  linewidth=.5);  
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.set_xticklabels(CATEGORIES)
ax.set_yticklabels(CATEGORIES)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.setp(ax.get_xticklabels(), rotation=90, horizontalalignment='right')
plt.setp(ax.get_yticklabels(), rotation=0, horizontalalignment='right')
plt.savefig(load_path+model_name1+'_cm.png',bbox_inches='tight')
plt.show()

# %%
#PLot fractional incorrect misclassifications

incorr_fraction = 1 - np.diag(cm) / np.sum(cm, axis=1)

fig, ax = plt.subplots(figsize=(12,8))
plt.bar(np.arange(cat_len), incorr_fraction)
plt.xlabel('True Label')
plt.ylabel('Fraction of incorrect predictions')
plt.xticks(np.arange(cat_len), CATEGORIES)
plt.savefig(load_path+model_name1+'_incorrect_percentage.png',bbox_inches='tight')
plt.show()

# %%
#CHECK RANDOM IMAGES FROM TESTED DATA WHETHER RIGHT OR WRONG

i = random.randint(1,cat_len)
plt.imshow(X_new[i,:,:,2]) 
print("Predicted Label: ", CATEGORIES[int(y_pred[i])])
print("True Label: ", CATEGORIES[int(y_test1[i])])

# %% [markdown]
# # Colourful mediapipe testing with VA_create_3.0

# %%
import cv2
import mediapipe as mp
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results
    
def draw_landmarks(image, results):   
    #face
    mp_drawing.draw_landmarks(
        image,
        results.face_landmarks,
        mp_holistic.FACEMESH_CONTOURS,
        landmark_drawing_spec=None,
        connection_drawing_spec=mp_drawing_styles
        .get_default_face_mesh_contours_style())
#     #pose
#     mp_drawing.draw_landmarks(
#         image,
#         results.pose_landmarks,
#         mp_holistic.POSE_CONNECTIONS,
#         landmark_drawing_spec=mp_drawing_styles
#         .get_default_pose_landmarks_style())
    
    #left hand
    mp_drawing.draw_landmarks(
        image,
        results.left_hand_landmarks,
        mp_holistic.HAND_CONNECTIONS,
#         landmark_drawing_spec=None,
            mp_drawing_styles.get_default_hand_landmarks_style(),
            mp_drawing_styles.get_default_hand_connections_style())
    # right hand
    mp_drawing.draw_landmarks(
        image,
        results.right_hand_landmarks,
        mp_holistic.HAND_CONNECTIONS,
#         landmark_drawing_spec=None,
            mp_drawing_styles.get_default_hand_landmarks_style(),
            mp_drawing_styles.get_default_hand_connections_style())

# %%
## For veryyyyyyyy beautiful webcam input:

cap = cv2.VideoCapture(0)
org = (20, 20)  
org1 = (310, 20) 
fontScale = 0.65  
font = cv2.FONT_HERSHEY_SIMPLEX
# Blue color in BGR
color = (130, 0, 0)  
# Line thickness of 2 px
thickness = 1 
thickness1 = -1
start_point = (0,0)
end_point = (480,30)
color1 = (255, 255, 255)  
cls='R'
with mp_holistic.Holistic(min_detection_confidence=0.5,min_tracking_confidence=0.5) as holistic:
      while cap.isOpened():
        #image from feeder
        r, img_array = cap.read()
        img_array = cv2.flip(img_array, 1)
        #webcam
        img_array = img_array[:, 80:560, :]
        #dslr
#         img_array = cv2.resize(img_array[:, 224:800, :],(480,480))
        
        image, results = mediapipe_detection(img_array, holistic)
        draw_landmarks(image, results)
        if not (results.left_hand_landmarks or results.right_hand_landmarks):
            continue

        # white background
        img = np.zeros([480,480,3],dtype=np.uint8)
        img.fill(255) 
        draw_landmarks(img, results)

        # for prediction
        IMG_SIZE=128
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        X = np.array(img).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
        X = X.astype('float32')
        X /= 255
        X = np.array(X)
        Y = model1.predict(X,verbose=0)

        if np.max(Y)>0.2:
            # for display
            image = cv2.rectangle(image, start_point, end_point, color1, thickness1)
            image = cv2.rectangle(image, (0,30), (480,30), color, 2)
            image = cv2.putText(image,"Prediction: "+ CATEGORIES[np.argmax(Y)], org, font, 
                   fontScale, color, thickness, cv2.LINE_AA)
            image = cv2.putText(image,"Accuracy: "+ "%.2f" % np.max(Y), org1, font, 
                   fontScale, color, thickness, cv2.LINE_AA)
#             if CATEGORIES[np.argmax(Y)]==cls:
            if np.max(Y)>0.8:
                cv2.imwrite(load_path+'/99.79_misc_rajesh/mp_'+
                            CATEGORIES[np.argmax(Y)]+'_'+str(np.max(Y))+'.jpg',image)
                cv2.imwrite(load_path+'/99.79_misc_rajesh/ori_'+
                            CATEGORIES[np.argmax(Y)]+'_'+str(np.max(Y))+'.jpg',img_array)


        cv2.imshow('Realtime testing', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
                break
# close the camera
cap.release()

# close all the opened windows
cv2.destroyAllWindows()
